# %%
from iam_intercomparison_figure import iam_intercomparison_figure
import pandas as pd

# %% [markdown]
# ## Study 3

# %% [markdown]
# ### Importing Study 3 Data

# %%
study3_df =  pd.read_csv('data/study3_df.csv')
study3_hist_df =  pd.read_csv('data/study3_hist_df.csv')
study3_AR6_df =  pd.read_csv('data/study3_AR6_df.csv')

# %% [markdown]
# ### Plotting Study 3 Data

# %%
iam_intercomparison_figure(hist_df=study3_hist_df, AR6_df=study3_AR6_df, study_df=study3_df,
                 scenarios= ['NDC_LTT', 'NDC_LTT_limBIO', 'NDC_LTT_limCCS','NDC_LTT_limRES'],
                 region_list=['EU27','EU28'],
                 box_cats=['C1','C2','C3'])
# Out:
# C:\Users\salexandrou\PycharmProjects\IAMCOMPACT\iam_intercomparison_figure.py:130: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0,0,1,0.95]);

# %% [markdown]
# ## Study 4

# %% [markdown]
# ### Importing Study 4 Data

# %%
study4_df =  pd.read_csv('data/study4_df.csv')
study4_hist_df =  pd.read_csv('data/study4_hist_df.csv')
study4_AR6_df =  pd.read_csv('data/study4_AR6_df.csv')

# %% [markdown]
# ### Plotting Study 4 Data

# %%
iam_intercomparison_figure(hist_df=study4_hist_df, AR6_df=study4_AR6_df, study_df=study4_df,
                 scenarios=['NDC_LTT','CBAM','INDEPENDENCE'],
                 region_list=['EU28','EU27'],
                 box_cats=['C2','C3','C5'])
# Out:
# C:\Users\salexandrou\PycharmProjects\IAMCOMPACT\iam_intercomparison_figure.py:130: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0,0,1,0.95]);

# %% [markdown]
# ## Study 6

# %% [markdown]
# ### Importing Study 6 Data

# %%
study6_df =  pd.read_csv('data/study6_df.csv')
study6_hist_df =  pd.read_csv('data/study6_hist_df.csv')
study6_AR6_df =  pd.read_csv('data/study6_AR6_df.csv')

# %% [markdown]
# ### Plotting Study 6 Data

# %%
iam_intercomparison_figure(hist_df=study6_hist_df, AR6_df = study6_AR6_df, study_df = study6_df,
                 scenarios=['Fragmented','NDC_LTT_baseWACC','NDC_EI_baseWACC'],
                 region_list=['World'],
                 box_cats=['C2','C3','C5']);
# Out:
# C:\Users\salexandrou\PycharmProjects\IAMCOMPACT\iam_intercomparison_figure.py:130: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0,0,1,0.95]);

# %% [markdown]
# ## Study 7

# %% [markdown]
# ### Importing Study 7 Data

# %%
study7_df =  pd.read_csv('data/study7_df.csv')
study7_hist_df =  pd.read_csv('data/study7_hist_df.csv')
study7_AR6_df =  pd.read_csv('data/study7_AR6_df.csv')

# %% [markdown]
# ### Plotting Study 7 Data

# %%
iam_intercomparison_figure(hist_df=study7_hist_df, AR6_df=study7_AR6_df, study_df=study7_df,
                 scenarios=['NDC_LTT','NDC_LTT_TRANS'],
                 region_list=['EU27','EU28'],
                 box_cats=['C1','C2','C3'])
# Out:
# C:\Users\salexandrou\PycharmProjects\IAMCOMPACT\iam_intercomparison_figure.py:130: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0,0,1,0.95]);
